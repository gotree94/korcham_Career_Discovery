# %% [markdown]
# # 1-2. ROS SIMPLE Subscribe

# %% [markdown]
# #### 모듈 추가

# %%
import rospy
from std_msgs.msg import String

# %% [markdown]
# #### 데이터를 수신 처리

# %%
def callback(data):
    rospy.loginfo(rospy.get_caller_id() + "I heard %s", data.data)

# %% [markdown]
# #### 노드 생성

# %%
rospy.init_node('listener', anonymous=True)

# %% [markdown]
# #### Subscriber 객체 생성

# %%
rospy.Subscriber("chatter", String, callback)
# Out:
# [INFO] [1659427184.737654]: /listener_12796_1659427184313I heard hello world 1659427184.7282639
# [INFO] [1659427184.839673]: /listener_12796_1659427184313I heard hello world 1659427184.8283381
# [INFO] [1659427184.939081]: /listener_12796_1659427184313I heard hello world 1659427184.9283154
# [INFO] [1659427185.044614]: /listener_12796_1659427184313I heard hello world 1659427185.0285366
# [INFO] [1659427185.136981]: /listener_12796_1659427184313I heard hello world 1659427185.128366
# [INFO] [1659427185.237151]: /listener_12796_1659427184313I heard hello world 1659427185.2282982
# [INFO] [1659427185.339127]: /listener_12796_1659427184313I heard hello world 1659427185.3283503
# [INFO] [1659427185.436786]: /listener_12796_1659427184313I heard hello world 1659427185.4282954
# [INFO] [1659427185.537119]: /listener_12796_1659427184313I heard hello world 1659427185.5283148
# [INFO] [1659427185.638067]: /listener_12796_1659427184313I heard hello world 1659427185.6283026
# ...
