# %%
import Jetson.GPIO  as GPIO
import time
Motion = 'UART2_RTS'
GPIO.setup(Motion, GPIO.IN)
while True:
    value = GPIO.input(Motion)
    if(value == 0):
        print("모션 감지")
        time.sleep(0.3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-51f70e1f22d0> in <module>
#       2 import time
#       3 Motion = 'UART2_RTS'
# ----> 4 GPIO.setup(Motion, GPIO.IN)
#       5 while True:
#       6     value = GPIO.input(Motion)
#
# /usr/lib/python3/dist-packages/Jetson/GPIO/gpio.py in setup(channels, direction, pull_up_down, initial)
#     338 # and is only valid when direction is OUT
#     339 def setup(channels, direction, pull_up_down=PUD_OFF, initial=None):
# --> 340     ch_infos = _channels_to_infos(channels, need_gpio=True)
#     341
#     342     # check direction is valid
#
# /usr/lib/python3/dist-packages/Jetson/GPIO/gpio.py in _channels_to_infos(channels, need_gpio, need_pwm)
#     117
#     118 def _channels_to_infos(channels, need_gpio=False, need_pwm=False):
# --> 119     _validate_mode_set()
# ...
